# %% [markdown]
# # Machine Learning - Regression example

# %% [markdown]
# ###### Links: [House prices dataset (Kaggle)](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)  |  [Article (TowardsDataScience)](https://towardsdatascience.com/machine-learning-with-python-regression-complete-tutorial-47268e546cea)

# %% [markdown]
# ### 0 - Setup

# %% [markdown]
# ###### Import pckgs

# %%
import warnings
warnings.filterwarnings("ignore")
from ml_utils import *

# %%
import pandas as pd

# %% [markdown]
# ###### Import data

# %%
dtf = pd.read_csv("data_houses.csv")
cols = ["OverallQual","GrLivArea","GarageCars","GarageArea","TotalBsmtSF","FullBath","YearBuilt","YearRemodAdd",
        "LotFrontage","MSSubClass"]
dtf = dtf[["Id"]+cols+["SalePrice"]]
dtf.head()
# Out:
#    Id  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  FullBath  \
# 0   1            7       1710           2         548          856         2
# 1   2            6       1262           2         460         1262         2
# 2   3            7       1786           2         608          920         2
# 3   4            7       1717           3         642          756         1
# 4   5            8       2198           3         836         1145         2
#
#    YearBuilt  YearRemodAdd  LotFrontage  MSSubClass  SalePrice
# 0       2003          2003         65.0          60     208500
# 1       1976          1976         80.0          20     181500
# 2       2001          2002         68.0          60     223500
# 3       1915          1970         60.0          70     140000
# 4       2000          2000         84.0          60     250000

# %%
dtf = dtf.set_index("Id")
dtf = dtf.rename(columns={"SalePrice":"Y"})

# %% [markdown]
# ### 1 - Data Analysis

# %% [markdown]
# ###### Group variables by type
# - pk: Id
# - y: SalePrice
# - info: OverallQual, YearBuilt, YearRemodAdd, MSSubClass
# - inside: GrLivArea, FullBath
# - outside: LotFrontage
# - perks: GarageCars, GarageArea, TotalBsmtSF

# %%
features = []

# %% [markdown]
# ###### Target Variable

# %%
freqdist_plot(dtf, "Y", box_logscale=True, figsize=(10,5))

# %%
#-> Average House price: 180,921

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
corr = corr_matrix(dtf, method="pearson", negative=False, lst_filters=["Y"], figsize=(15,1))

# %% [markdown]
# ###### Info: OverallQual, YearBuilt, YearRemodAdd, GarageYrBlt, MSSubClass

# %%
#--- OverallQual ---#
freqdist_plot(dtf, "OverallQual", figsize=(5,3))
# Out:
# --- got error ---
# Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
bivariate_plot(dtf, x="OverallQual", y="Y", figsize=(15,5))
# Out:
# --- got error ---
# cannot import name 'recode_for_categories' from 'pandas.core.arrays.categorical' (/home/evdo/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py)

# %%
#-> OverallQual is Predctive: the higher the quality the higher the price.
features.append("OverallQual")

# %%
#--- YearBuilt ---#
bivariate_plot(dtf, x="YearBuilt", y="Y", figsize=(10,3))
# Out:
# --- got error ---
# cannot import name 'recode_for_categories' from 'pandas.core.arrays.categorical' (/home/evdo/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py)

# %%
#-> YearBuilt is Predctive: the more recent the construction the higher the price.
features.append("YearBuilt")

# %%
#--- YearRemodAdd ---#
bivariate_plot(dtf, x="YearRemodAdd", y="Y", figsize=(10,3))
# Out:
# --- got error ---
# cannot import name 'recode_for_categories' from 'pandas.core.arrays.categorical' (/home/evdo/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py)

# %%
#-> YearRemodAdd is Predctive: the more recent the renovation the higher the price.
features.append("YearRemodAdd")

# %%
#--- MSSubClass ---#
freqdist_plot(dtf, "MSSubClass", figsize=(5,3))
# Out:
# --- got error ---
# Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# this variable is tricky as it has 15 classes, so I will plot manually in one boxplot
fig, ax = plt.subplots(figsize=(15,5))
sns.catplot(x="MSSubClass", y="Y", data=dtf, kind="box", ax=ax)
ax.grid(True)
plt.close()

# %%
# I will summarise this categories in clusters
MSSubClass_clusters = {"min":[30,45,180], "max":[60,120], "mean":[]}
dtf = add_feature_clusters(dtf, "MSSubClass", dic_clusters_mapping=MSSubClass_clusters, dropx=False)
dtf[["MSSubClass","MSSubClass_cluster","Y"]].head()
# Out:
#     MSSubClass MSSubClass_cluster       Y
# Id
# 1           60                max  208500
# 2           20               mean  181500
# 3           60                max  223500
# 4           70               mean  140000
# 5           60                max  250000

# %%
bivariate_plot(dtf, x="MSSubClass_cluster", y="Y", figsize=(15,5))
# Out:
# --- got error ---
# cannot import name 'recode_for_categories' from 'pandas.core.arrays.categorical' (/home/evdo/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py)

# %%
#-> MSSubClass_cluster is Predictive: different lot classes (clusters) lead to different house prices.
features.append("MSSubClass_cluster")

# %% [markdown]
# ###### Inside: GrLivArea, FullBath, TotRmsAbvGrd

# %%
#--- GrLivArea ---#
bivariate_plot(dtf, x="GrLivArea", y="Y", figsize=(10,3))

# %%
#-> GrLivArea is Predctive: the larger the living area the higher the price.
features.append("GrLivArea")

# %%
#--- FullBath ---#
freqdist_plot(dtf, "FullBath", figsize=(5,3))

# %%
bivariate_plot(dtf, x="FullBath", y="Y", figsize=(15,5))

# %%
# I can't tell if the samples are statistically significant, I'll test that:
coeff, p = test_corr(dtf, x="FullBath", y="Y")
# Out:
# Anova F: the variables are Correlated (p-value: 0.0)

# %%
#-> FullBath is Predctive: the more bathrooms there are the higher the price.
features.append("FullBath")

# %% [markdown]
# ###### Outside: LotFrontage

# %%
#--- LotFrontage ---#
bivariate_plot(dtf, x="LotFrontage", y="Y", figsize=(10,3))

# %%
# I can't tell if the samples are statistically significant, I'll test that:
coeff, p = test_corr(dtf, x="LotFrontage", y="Y")
# Out:
# Pearson Correlation: 0.352 Significant (p-value: 0.0)

# %%
#-> LotFrontage is Predictive: the larger is the street connected to property the higher is the house price.
features.append("LotFrontage")

# %% [markdown]
# ###### Perks: GarageCars, GarageArea, TotalBsmtSF, Fireplaces

# %%
#--- GarageCars ---#
bivariate_plot(dtf, x="GarageCars", y="Y", figsize=(15,5))

# %%
#-> GarageCars is Predictive: the larger is the garage (in cars) the higher is the house price.
features.append("GarageCars")

# %%
#--- GarageArea ---#
bivariate_plot(dtf, x="GarageArea", y="Y", figsize=(10,3))

# %%
#-> GarageArea is Predictive: the larger is the garage (is sqrfeet) the higher is the house price.
features.append("GarageArea")

# %%
#--- TotalBsmtSF, ---#
bivariate_plot(dtf, x="TotalBsmtSF", y="Y", figsize=(10,3))

# %%
#%matplotlib notebook
cross_distributions(dtf, x1="TotalBsmtSF", x2="GrLivArea", y="Y", figsize=(7,4))
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#-> TotalBsmtSF, is Predictive: the larger is the basement the higher is the house price.
features.append("TotalBsmtSF")

# %% [markdown]
# ###### Summary

# %%
dtf = dtf[features+["Y"]]
dtf.head()
# Out:
#     OverallQual  YearBuilt  YearRemodAdd MSSubClass_cluster  GrLivArea  \
# Id
# 1             7       2003          2003                max       1710
# 2             6       1976          1976               mean       1262
# 3             7       2001          2002                max       1786
# 4             7       1915          1970               mean       1717
# 5             8       2000          2000                max       2198
#
#     FullBath  LotFrontage  GarageCars  GarageArea       Y
# Id
# 1          2         65.0           2         548  208500
# 2          2         80.0           2         460  181500
# 3          2         68.0           2         608  223500
# 4          1         60.0           3         642  140000
# 5          2         84.0           3         836  250000

# %% [markdown]
# ### 2 - Preprocessing

# %% [markdown]
# ###### To do:
# - Dataset partitioning
# - Resample
# - Treat missings
# - Encode categorical data
# - Scaling
# - Preprocess Test data

# %%
check = data_preprocessing(dtf, y="Y", task="regression")
# Out:
# --- check missing ---
# WARNING: LotFrontage --> 259 Nas
# --- check categorical data ---
# WARNING: MSSubClass_cluster --> 3 categories
# --- split train/test ---
#    OK: step skipped
# --- scaling ---
#    OK: step skipped

# %% [markdown]
# ###### Partitioning

# %%
dtf_train, dtf_test = dtf_partitioning(dtf, y="Y", test_size=0.3, shuffle=False)
# Out:
# X_train shape: (1022, 9) | X_test shape: (438, 9)
# y_train mean: 181713.25 | y_test mean: 179073.06
# 10 features: ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MSSubClass_cluster', 'GrLivArea', 'FullBath', 'LotFrontage', 'GarageCars', 'GarageArea']

# %%
dtf_train.head(3)
# Out:
#     OverallQual  YearBuilt  YearRemodAdd MSSubClass_cluster  GrLivArea  \
# Id
# 1             7       2003          2003                max       1710
# 2             6       1976          1976               mean       1262
# 3             7       2001          2002                max       1786
#
#     FullBath  LotFrontage  GarageCars  GarageArea       Y
# Id
# 1          2         65.0           2         548  208500
# 2          2         80.0           2         460  181500
# 3          2         68.0           2         608  223500

# %%
dtf_test.head(3)
# Out:
#       OverallQual  YearBuilt  YearRemodAdd MSSubClass_cluster  GrLivArea  \
# Id
# 1023            5       1930          1950               mean       1248
# 1024            7       2005          2006                max       1504
# 1025            8       1976          1976               mean       2898
#
#       FullBath  LotFrontage  GarageCars  GarageArea       Y
# Id
# 1023         1         52.0           1         160   87000
# 1024         2         43.0           2         437  191000
# 1025         2          NaN           2         665  287000

# %% [markdown]
# ###### Resample

# %%
# no need to resample.

# %% [markdown]
# ###### Missing values

# %%
dtf_train, lotfront_mean = fill_na(dtf_train, x="LotFrontage")
# Out:
# --- Replacing Nas with: 69.78579881656805 ---

# %% [markdown]
# ###### Categorical Encoding

# %%
dtf_train = add_dummies(dtf_train, x="MSSubClass_cluster", dropx=True)
# Out:
#    MSSubClass_cluster  MSSubClass_cluster_mean  MSSubClass_cluster_min
# Id
# 1                 max                        0                       0
# 2                mean                        1                       0
# 3                 max                        0                       0
# 4                mean                        1                       0
# 5                 max                        0                       0

# %%
# since the other catogories indicate all quantities, there's no need to encode them.

# %% [markdown]
# ###### Scaling

# %%
scalerX = preprocessing.RobustScaler(quantile_range=(25.0, 75.0))
scalerY = preprocessing.RobustScaler(quantile_range=(25.0, 75.0))

# %%
dtf_train, scalerX, scalerY = scaling(dtf_train, y="Y", scalerX=scalerX, scalerY=scalerY, task="regression")

# %%
dtf_train.head()
# Out:
#     OverallQual  YearBuilt  YearRemodAdd  GrLivArea  FullBath  LotFrontage  \
# Id
# 1           0.5   0.617021      0.243243   0.395177       0.0    -0.265878
# 2           0.0   0.042553     -0.486486  -0.301828       0.0     0.567456
# 3           0.5   0.574468      0.216216   0.513419       0.0    -0.099211
# 4           0.5  -1.255319     -0.648649   0.406068      -1.0    -0.543655
# 5           1.0   0.553191      0.162162   1.154415       0.0     0.789678
#
#     GarageCars  GarageArea  MSSubClass_cluster_mean  MSSubClass_cluster_min  \
# Id
# 1          0.0    0.283333                     -1.0                     0.0
# 2          0.0   -0.083333                      0.0                     0.0
# 3          0.0    0.533333                     -1.0                     0.0
# 4          1.0    0.675000                      0.0                     0.0
# 5          1.0    1.483333                     -1.0                     0.0
#
#            Y
# Id
# 1   0.526684
# 2   0.208944
# 3   0.703207
# 4  -0.279435
# 5   1.015063

# %%
dtf_overview(dtf_train)
# Out:
# Shape: (1022, 11)
# -----------------
# OverallQual --> Type:cat | Nas: 0(0%) | Categories: 10
# YearBuilt --> Type:num | Nas: 0(0%) | Min-Max: (-2)-(0)
# YearRemodAdd --> Type:num | Nas: 0(0%) | Min-Max: (-1)-(0)
# GrLivArea --> Type:num | Nas: 0(0%) | Min-Max: (-1)-(5)
# FullBath --> Type:cat | Nas: 0(0%) | Categories: 4
# LotFrontage --> Type:num | Nas: 0(0%) | Min-Max: (-2)-(13)
# GarageCars --> Type:cat | Nas: 0(0%) | Categories: 5
# GarageArea --> Type:num | Nas: 0(0%) | Min-Max: (-2)-(3)
# MSSubClass_cluster_mean --> Type:cat | Nas: 0(0%) | Categories: 2
# MSSubClass_cluster_min --> Type:cat | Nas: 0(0%) | Categories: 2
# Y --> Type:num | Nas: 0(0%) | Min-Max: (-1)-(6)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-29e34caa8fec> in <module>
# ----> 1 dtf_overview(dtf_train)
#
# ~/Documents/GitHub/DataScience_ArtificialIntelligence_Utils/machine_learning/ml_utils.py in dtf_overview(dtf, max_cat, figsize)
#      90         else:
#      91             heatmap[k] = heatmap[k].apply(lambda x: 0 if x is False else 1)
# ---> 92     sns.heatmap(heatmap, vmin=0, vmax=1, cbar=False, ax=ax).set_title('Dataset Overview')
#      93     #plt.setp(plt.xticks()[1], rotation=0)
#      94     plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     111
#     112         # Validate the mask and convet to DataFrame
# --> 113         mask = _matrix_mask(data, mask)
#     114
#     115         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in _matrix_mask(data, mask)
#      90     # This works around an issue where `plt.pcolormesh` doesn't represent
#      91     # missing data properly
# ---> 92     mask = mask | pd.isnull(data)
#      93
#      94     return mask
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value, level)
#    5372         ...                    'sale': [55, 40, 84, 31]})
#    5373         >>> df
# -> 5374            month  year  sale
#    5375         0      1  2012    55
#    5376         1      4  2014    40
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arith_op(left, right)
#    5365         DataFrame.reindex : Change to new indices or expand indices.
#    5366         DataFrame.reindex_like : Change to same indices as other DataFrame.
# -> 5367
#    5368         Examples
#    5369         --------
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in <module>
#      15 from pandas._config import get_option
#      16
# ---> 17 from pandas._typing import FuncType
#      18
#      19 from pandas.core.computation.check import NUMEXPR_INSTALLED
#
# ImportError: cannot import name 'FuncType' from 'pandas._typing' (/home/evdo/anaconda3/lib/python3.7/site-packages/pandas/_typing.py)

# %% [markdown]
# ###### Preprocess Test data

# %%
## Na
dtf_test = fill_na(dtf_test, x="LotFrontage", value=lotfront_mean)
# Out:
# --- Replacing Nas with: 69.78579881656805 ---

# %%
## Categorical
dtf_test = add_dummies(dtf_test, x="MSSubClass_cluster", dropx=True)
# Out:
#      MSSubClass_cluster  MSSubClass_cluster_mean  MSSubClass_cluster_min
# Id
# 1023               mean                        1                       0
# 1024                max                        0                       0
# 1025               mean                        1                       0
# 1026               mean                        1                       0
# 1027               mean                        1                       0

# %%
dtf_test = dtf_test[dtf_train.columns]
dtf_test.head()
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  GrLivArea  FullBath  LotFrontage  \
# Id
# 1023            5       1930          1950       1248         1    52.000000
# 1024            7       2005          2006       1504         2    43.000000
# 1025            8       1976          1976       2898         2    69.785799
# 1026            5       1972          1972        882         1    70.000000
# 1027            5       1960          1960       1264         1    73.000000
#
#       GarageCars  GarageArea  MSSubClass_cluster_mean  MSSubClass_cluster_min  \
# Id
# 1023           1         160                        1                       0
# 1024           2         437                        0                       0
# 1025           2         665                        1                       0
# 1026           2         461                        1                       0
# 1027           2         461                        1                       0
#
#            Y
# Id
# 1023   87000
# 1024  191000
# 1025  287000
# 1026  112500
# 1027  167500

# %%
## Scale
dtf_test, _, _ = scaling(dtf_test, y="Y", scalerX=scalerX, scalerY=scalerY, fitted=True, task="regression")

# %%
dtf_overview(dtf_test)
# Out:
# Shape: (438, 11)
# -----------------
# OverallQual --> Type:cat | Nas: 0(0%) | Categories: 9
# YearBuilt --> Type:num | Nas: 0(0%) | Min-Max: (-2)-(0)
# YearRemodAdd --> Type:num | Nas: 0(0%) | Min-Max: (-1)-(0)
# GrLivArea --> Type:num | Nas: 0(0%) | Min-Max: (-1)-(6)
# FullBath --> Type:cat | Nas: 0(0%) | Categories: 4
# LotFrontage --> Type:num | Nas: 0(0%) | Min-Max: (-2)-(13)
# GarageCars --> Type:cat | Nas: 0(0%) | Categories: 5
# GarageArea --> Type:num | Nas: 0(0%) | Min-Max: (-2)-(3)
# MSSubClass_cluster_mean --> Type:cat | Nas: 0(0%) | Categories: 2
# MSSubClass_cluster_min --> Type:cat | Nas: 0(0%) | Categories: 2
# Y --> Type:num | Nas: 0(0%) | Min-Max: (52500)-(745000)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-53-eeeb7b2ec695> in <module>
# ----> 1 dtf_overview(dtf_test)
#
# ~/Documents/GitHub/DataScience_ArtificialIntelligence_Utils/machine_learning/ml_utils.py in dtf_overview(dtf, max_cat, figsize)
#      90         else:
#      91             heatmap[k] = heatmap[k].apply(lambda x: 0 if x is False else 1)
# ---> 92     sns.heatmap(heatmap, vmin=0, vmax=1, cbar=False, ax=ax).set_title('Dataset Overview')
#      93     #plt.setp(plt.xticks()[1], rotation=0)
#      94     plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     111
#     112         # Validate the mask and convet to DataFrame
# --> 113         mask = _matrix_mask(data, mask)
#     114
#     115         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in _matrix_mask(data, mask)
#      90     # This works around an issue where `plt.pcolormesh` doesn't represent
#      91     # missing data properly
# ---> 92     mask = mask | pd.isnull(data)
#      93
#      94     return mask
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value, level)
#    5372         ...                    'sale': [55, 40, 84, 31]})
#    5373         >>> df
# -> 5374            month  year  sale
#    5375         0      1  2012    55
#    5376         1      4  2014    40
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arith_op(left, right)
#    5365         DataFrame.reindex : Change to new indices or expand indices.
#    5366         DataFrame.reindex_like : Change to same indices as other DataFrame.
# -> 5367
#    5368         Examples
#    5369         --------
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in <module>
#      15 from pandas._config import get_option
#      16
# ---> 17 from pandas._typing import FuncType
#      18
#      19 from pandas.core.computation.check import NUMEXPR_INSTALLED
#
# ImportError: cannot import name 'FuncType' from 'pandas._typing' (/home/evdo/anaconda3/lib/python3.7/site-packages/pandas/_typing.py)

# %% [markdown]
# ### 3 - Baseline (xgboost)

# %% [markdown]
# ###### Plan:
# - Feature Selection: by correlation, by p-value, by importance
# - Model Design
# - Train / Test
# - Evaluate
# - Explainability
# - Visualize model

# %% [markdown]
# ###### Features Selection

# %%
#--- correlation ---#
corr = corr_matrix(dtf_train, method="pearson", negative=False, annotation=True, figsize=(15,7))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-ddc37333a319> in <module>
#       1 #--- correlation ---#
# ----> 2 corr = corr_matrix(dtf_train, method="pearson", negative=False, annotation=True, figsize=(15,7))
#
# ~/Documents/GitHub/DataScience_ArtificialIntelligence_Utils/machine_learning/ml_utils.py in corr_matrix(dtf, method, negative, lst_filters, annotation, figsize)
#     382     dtf_corr = dtf_corr if negative is True else dtf_corr.abs()
#     383     fig, ax = plt.subplots(figsize=figsize)
# --> 384     sns.heatmap(dtf_corr, annot=annotation, fmt='.2f', cmap="YlGnBu", ax=ax, cbar=True, linewidths=0.5)
#     385     plt.title(method + " correlation")
#     386     return dtf_corr
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     111
#     112         # Validate the mask and convet to DataFrame
# --> 113         mask = _matrix_mask(data, mask)
#     114
#     115         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in _matrix_mask(data, mask)
#      90     # This works around an issue where `plt.pcolormesh` doesn't represent
#      91     # missing data properly
# ---> 92     mask = mask | pd.isnull(data)
#      93
#      94     return mask
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value, level)
#    5372         ...                    'sale': [55, 40, 84, 31]})
#    5373         >>> df
# -> 5374            month  year  sale
#    5375         0      1  2012    55
#    5376         1      4  2014    40
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arith_op(left, right)
#    5365         DataFrame.reindex : Change to new indices or expand indices.
#    5366         DataFrame.reindex_like : Change to same indices as other DataFrame.
# -> 5367
#    5368         Examples
#    5369         --------
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in <module>
#      15 from pandas._config import get_option
#      16
# ---> 17 from pandas._typing import FuncType
#      18
#      19 from pandas.core.computation.check import NUMEXPR_INSTALLED
#
# ImportError: cannot import name 'FuncType' from 'pandas._typing' (/home/evdo/anaconda3/lib/python3.7/site-packages/pandas/_typing.py)

# %%
pps = pps_matrix(dtf_train, annotation=True, figsize=(15,7))

# %%
#--- p values ---#
dic_feat_sel = features_selection(dtf_train, y="Y", task="regression", top=10, figsize=(10,5))

# %%
#--- importance ---#
model = ensemble.RandomForestRegressor(n_estimators=100, criterion="mse", random_state=0)

feat_imp = features_importance(X=dtf_train.drop("Y",axis=1).values, y=dtf_train["Y"].values, 
                               X_names=dtf_train.drop("Y",axis=1).columns.tolist(), 
                               model=model, task="regression", figsize=(15,5))
# Out:
# --- model used ---
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-15616aeb3b7f> in <module>
#       4 feat_imp = features_importance(X=dtf_train.drop("Y",axis=1).values, y=dtf_train["Y"].values,
#       5                                X_names=dtf_train.drop("Y",axis=1).columns.tolist(),
# ----> 6                                model=model, task="regression", figsize=(15,5))
#
# ~/Documents/GitHub/DataScience_ArtificialIntelligence_Utils/machine_learning/ml_utils.py in features_importance(X, y, X_names, model, task, figsize)
#     784     fig.suptitle("Features Importance", fontsize=20)
#     785     ax[0].title.set_text('variables')
# --> 786     dtf_importances[["IMPORTANCE"]].sort_values(by="IMPORTANCE").plot(kind="barh", legend=False, ax=ax[0]).grid(axis="x")
#     787     ax[0].set(ylabel="")
#     788     ax[1].title.set_text('cumulative')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792         This function makes calls to this accessor `__call__` method compatible
#     793         with the previous `SeriesPlotMethods.__call__` and
# --> 794         `DataFramePlotMethods.__call__`. Those had slightly different
#     795         signatures, since `DataFramePlotMethods` accepted `x` and `y`
#     796         parameters.
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60     # registered) causes problems in matplotlib 2 (converters seem to not
#      61     # work)
# ---> 62     import matplotlib.pyplot as plt
#      63
#      64     if kwargs.pop("reuse_plot", False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277             return 1
#     278         else:
# --> 279             return self.data.shape[1]
#     280
#     281     def draw(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     402         # GH32073: cast to float if values contain nulled integers
#     403         if (
# --> 404             is_integer_dtype(data.dtype) or is_float_dtype(data.dtype)
#     405         ) and is_extension_array_dtype(data.dtype):
#     406             return data.to_numpy(dtype="float", na_value=np.nan)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3425                 if isinstance(self.columns, MultiIndex):
#    3426                     return self._getitem_multilevel(key)
# -> 3427                 return self._get_item_cache(key)
#    3428
#    3429         # Do we have a slicer (on rows)?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309     div: Callable[[Series, Any], Series]
#     310     rdiv: Callable[[Series, Any], Series]
# --> 311
#     312     # ----------------------------------------------------------------------
#     313     # Constructors
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710     Parameters
#     711     ----------
# --> 712     data : List[Type[dataclass]]
#     713
#     714     Returns
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231     -------
#    1232     ndarray or ExtensionArray
# -> 1233     """
#    1234     if (
#    1235         values.dtype.kind in ["m", "M"]
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# -> selection
X_names = ['OverallQual', 'GrLivArea', 'TotalBsmtSF', 'YearBuilt', 'GarageArea']

# %% [markdown]
# ###### Model Design

# %%
X_train = dtf_train[X_names].values
y_train = dtf_train["Y"].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-428f57acc174> in <module>
# ----> 1 X_train = dtf_train[X_names].values
#       2 y_train = dtf_train["Y"].values
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984         )
#    2985
# -> 2986         return xml_formatter.write_output()
#    2987
#    2988     # ----------------------------------------------------------------------
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283         Returns
#    1284         -------
# -> 1285         keyarr: Index
#    1286             New index (coinciding with 'key' if the axis is unique).
#    1287         values : array-like
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090         self._validate_key(key, axis)
#    1091
# -> 1092         # A collection of keys
#    1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             return self.obj.take(indexer, axis=axis)
#    1184
# -> 1185     def _convert_to_indexer(self, key, axis: int, is_setter: bool = False):
#    1186         """
#    1187         Convert indexing key into something we can use to do actual fancy
#
# KeyError: "['TotalBsmtSF'] not in index"

# %%
model = ensemble.GradientBoostingRegressor()

# %%
param_dic = {'learning_rate':[0.15,0.1,0.05,0.01,0.005,0.001],      #weighting factor for the corrections by new trees when added to the model
             'n_estimators':[100,250,500,750,1000,1250,1500,1750],  #number of trees added to the model
             'max_depth':[2,3,4,5,6,7],                             #maximum depth of the tree
             'min_samples_split':[2,4,6,8,10,20,40,60,100],         #sets the minimum number of samples to split
             'min_samples_leaf':[1,3,5,7,9],                        #the minimum number of samples to form a leaf
             'max_features':[2,3,4,5,6,7],                          #square root of features is usually a good starting point
             'subsample':[0.7,0.75,0.8,0.85,0.9,0.95,1]}            #the fraction of samples to be used for fitting the individual base learners. Values lower than 1 generally lead to a reduction of variance and an increase in bias.

# %%
# this takes a while
model = tune_regr_model(X_train, y_train, model, param_dic, scoring="r2", 
                        searchtype="RandomSearch", n_iter=1000, cv=5, figsize=(10,5))
# Out:
# --- RandomSearch ---
# Best Model parameters: {'subsample': 0.7, 'n_estimators': 1000, 'min_samples_split': 60, 'min_samples_leaf': 9, 'max_features': 5, 'max_depth': 7, 'learning_rate': 0.005}
# Best Model r2: 0.83
#
# --- Kfold Validation ---
# r2 mean - base model: 0.78  --> best model: 1.0

# %% [markdown]
# ###### Train / Test

# %%
X_test = dtf_test[X_names].values
y_test = dtf_test["Y"].values

# %%
model, predicted = fit_regr_model(model, X_train, y_train, X_test, scalerY)

# %% [markdown]
# ###### Evaluate

# %%
evaluate_regr_model(y_test, predicted, figsize=(25,5))
# Out:
# R2 (explained variance): 0.86
# Mean Absolute Perc Error (Σ(|y-pred|/y)/n): 0.11
# Mean Absolute Error (Σ|y-pred|/n): 20,070
# Root Mean Squared Error (sqrt(Σ(y-pred)^2/n)): 29,444
# Max Error: -170,285

# %% [markdown]
# ###### Explainability

# %%
i = 1
print("True:", "{:,.0f}".format(y_test[i]), "--> Pred:", "{:,.0f}".format(predicted[i]))

explainer_shap(model, X_names, X_instance=X_test[i], X_train=None, task="regression", top=10)
# Out:
# True: 191,000 --> Pred: 194,870

# %% [markdown]
# ###### Visualize model

# %%
model2d = linear_model.LinearRegression()
#model2d.set_params(**model.get_params())

# %%
#%matplotlib notebook
plot3d_regr_model(X_train, y_train, X_test, y_test, scalerY, model2d, rotate=(30,0), figsize=(7,5))
# Out:
# --- unsupervised: pca ---
# --- fitting 2d model ---
# --- plotting test set ---
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ### 4 - Model Desing & Testing (neural network)

# %% [markdown]
# ###### Plan:
# - Model Design
# - Train / Test
# - Evaluate
# - Explainability
# - Visualize model

# %% [markdown]
# ###### Model Design

# %%
X_names = dtf_train.drop("Y", axis=1).columns.tolist()
X_train = dtf_train.drop("Y", axis=1).values
y_train = dtf_train["Y"].values

X_train.shape
# Out:
# (1022, 10)

# %%
## define R2 metrics for Keras
def R2(y, y_hat):
    ss_res =  K.sum(K.square(y - y_hat)) 
    ss_tot = K.sum(K.square(y - K.mean(y))) 
    return ( 1 - ss_res/(ss_tot + K.epsilon()) )

# %%
# Deep neural network with fully connected layers
n_features = 11
model = models.Sequential(name="DeepNN", layers=[
    ### (layer input) & hidden layer 1
    layers.Dense(name="h1", input_dim=n_features, units=int(round((n_features+1)/2)), activation='relu'),
    layers.Dropout(name="drop1", rate=0.2),
    ### hidden layer 2
    layers.Dense(name="h2", units=int(round((n_features+1)/4)), activation='relu'),
    layers.Dropout(name="drop2", rate=0.2),
    ### layer output
    layers.Dense(name="output", units=1, activation='linear')
])
model.compile(optimizer='adam', loss='mean_absolute_error', metrics=[R2])

model.summary()
# Out:
# Model: "DeepNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  h1 (Dense)                  (None, 6)                 72
#
#  drop1 (Dropout)             (None, 6)                 0
#
#  h2 (Dense)                  (None, 3)                 21
#
#  drop2 (Dropout)             (None, 3)                 0
#
#  output (Dense)              (None, 1)                 4
#
# =================================================================
# Total params: 97
# Trainable params: 97
# Non-trainable params: 0
# _________________________________________________________________

# %%
visualize_nn(model, description=True, figsize=(10,8))

# %% [markdown]
# ###### Train / Test

# %%
X_test = dtf_test.drop("Y", axis=1).values
y_test = dtf_test["Y"].values

X_test.shape
# Out:
# (438, 10)

# %%
import os
os.getcwd()
# Out:
# '/home/evdo/Documents/GitHub/DataScience_ArtificialIntelligence_Utils/machine_learning'

# %%
model, predicted = fit_dl_regr(X_train, y_train, X_test, scalerY, model, batch_size=32, epochs=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-a1c266184b37> in <module>
# ----> 1 model, predicted = fit_dl_regr(X_train, y_train, X_test, scalerY, model, batch_size=32, epochs=100)
#
# ~/Documents/GitHub/DataScience_ArtificialIntelligence_Utils/machine_learning/ml_utils.py in fit_dl_regr(X_train, y_train, X_test, scalerY, model, batch_size, epochs, verbose)
#    1213
#    1214     ## train
# -> 1215     training = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, shuffle=True, verbose=verbose, validation_split=0.3)
#    1216     if epochs > 1:
#    1217         utils_plot_keras_training(training)
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "/home/evdo/anaconda3/lib/python3.7/site-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/home/evdo/anaconda3/lib/python3.7/site-packages/keras/engine/training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/evdo/anaconda3/lib/python3.7/site-packages/keras/engine/training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/evdo/anaconda3/lib/python3.7/site-packages/keras/engine/training.py", line 859, in train_step
#         y_pred = self(x, training=True)
#     File "/home/evdo/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/evdo/anaconda3/lib/python3.7/site-packages/keras/engine/input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "DeepNN" is incompatible with the layer: expected shape=(None, 11), found shape=(None, 10)

# %% [markdown]
# ###### Evaluate

# %%
evaluate_regr_model(y_test, predicted, figsize=(25,5))
# Out:
# R2 (explained variance): 0.7
# Mean Absolute Perc Error (Σ(|y-pred|/y)/n): 0.12
# Mean Absolute Error (Σ|y-pred|/n): 22,051
# Root Mean Squared Error (sqrt(Σ(y-pred)^2/n)): 43,146
# Max Error: -582,003

# %% [markdown]
# ###### Explainability

# %%
print("True:", "{:,.0f}".format(y_test[i]), "--> Pred:", "{:,.0f}".format(predicted[i]))

explainer_shap(model, X_names, X_instance=X_test[i], X_train=X_train, task="regression", top=10)
# Out:
# True: 191,000 --> Pred: 162,508

# %% [markdown]
# ###### Visualize model

# %%
model2d = models.Sequential()
### layer 1
model2d.add(layers.Dense(input_dim=2, units=int(round((11+1)/2)), kernel_initializer='normal', activation='relu'))
model2d.add(layers.Dropout(rate=0.2))
### layer 2
model2d.add(layers.Dense(units=int(round((11+1)/2)), kernel_initializer='normal', activation='relu'))
model2d.add(layers.Dropout(rate=0.2))
### layer output
model2d.add(layers.Dense(units=1, kernel_initializer='normal', activation='linear'))
model2d.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# %%
#%matplotlib notebook
plot3d_regr_model(X_train, y_train, X_test, y_test, scalerY, model2d, rotate=(30,0), figsize=(7,5))
# Out:
# --- unsupervised: pca ---
# --- fitting 2d model ---
# 1022/1022 [==============================] - 0s 50us/sample - loss: 0.5051 - mean_absolute_error: 0.5051
# --- plotting test set ---
# <img src="data:image/png;base64,..." width="700">
